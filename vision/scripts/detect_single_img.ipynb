# %%
from LegoDetect import LegoDetect
from PIL import Image, ImageDraw

img_path = '/home/utente/FoR-project/vision/rviz_screenshot_2023_12_18-13_30_45_png.rf.e8de920cfff777ae1c61d91b52c87940.jpg'
legoDetect = LegoDetect(img_path)


# center_list = []
# for index, lego in enumerate(legoDetect.lego_list, start=1):
#     print(index)
#     lego.show()
#     center_list.append(lego.center_point)

# Draw center points
# img = Image.open(img_path)
# draw = ImageDraw.Draw(img)
# draw.point(center_list, 'red')
# display(img)
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.10 torch-2.1.2+cu121 CPU (Intel Core(TM) i5-8400 2.80GHz)
# Setup complete ✅ (2 CPUs, 3.8 GB RAM, 32.7/97.4 GB disk)
#
# image 1/1 /home/utente/FoR-project/vision/rviz_screenshot_2023_12_18-13_30_45_png.rf.e8de920cfff777ae1c61d91b52c87940.jpg: 352x640 2 X1-Y1-Z2s, 2 X1-Y2-Z2s, 2 X1-Y3-Z2s, 2 X1-Y4-Z2s, 277.8ms
# Speed: 4.2ms preprocess, 277.8ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
# /home/utente/FoR-project/vision/rviz_screenshot_2023_12_18-13_30_45_png.rf.e8de920cfff777ae1c61d91b52c87940.jpg
# img size: 1920 x 1016
# tensor([1184.6946,  673.5394, 1339.4224,  748.0311])
# x1 =  1184 y1 =  673 x2 =  1339 y2 =  748
# tensor([ 922.2059,  578.8517, 1041.7336,  673.2246])
# x1 =  922 y1 =  578 x2 =  1041 y2 =  673
# tensor([ 952.3110,  662.3350, 1034.0266,  744.1240])
# x1 =  952 y1 =  662 x2 =  1034 y2 =  744
# tensor([832.1477, 658.2875, 920.3650, 765.9350])
# x1 =  832 y1 =  658 x2 =  920 y2 =  765
# tensor([1150.8539,  579.9962, 1194.5684,  639.4338])
# x1 =  1150 y1 =  579 x2 =  1194 y2 =  639
# tensor([745.8296, 686.6302, 790.6469, 753.5384])
# x1 =  745 y1 =  686 x2 =  790 y2 =  753
# tensor([807.9739, 597.5056, 850.6190, 674.0191])
# x1 =  807 y1 =  597 x2 =  850 y2 =  674
# tensor([1029.9382,  552.5391, 1121.3784,  615.8248])
# x1 =  1029 y1 =  552 x2 =  1121 y2 =  615
# Detected 8 object(s)
# <PIL.Image.Image image mode=RGB size=155x75>
# class = tensor([3.])
# id = tensor([3.])
# confidence = 0.94
# center_point = (1261, 710)
# center_point_uv = (659, 710)
# --> point cloud = ()
# --> point world = ()
# <PIL.Image.Image image mode=RGB size=119x95>
# class = tensor([3.])
# id = tensor([3.])
# confidence = 0.93
# center_point = (981, 625)
# center_point_uv = (939, 625)
# --> point cloud = ()
# --> point world = ()
# <PIL.Image.Image image mode=RGB size=82x82>
# class = tensor([1.])
# id = tensor([1.])
# confidence = 0.93
# center_point = (993, 703)
# center_point_uv = (927, 703)
# --> point cloud = ()
# --> point world = ()
# <PIL.Image.Image image mode=RGB size=88x107>
# class = tensor([2.])
# id = tensor([2.])
# confidence = 0.93
# center_point = (876, 711)
# center_point_uv = (1044, 711)
# --> point cloud = ()
# --> point world = ()
# <PIL.Image.Image image mode=RGB size=44x60>
# class = tensor([0.])
# id = tensor([0.])
# confidence = 0.91
# center_point = (1172, 609)
# center_point_uv = (748, 609)
# --> point cloud = ()
# --> point world = ()
# <PIL.Image.Image image mode=RGB size=45x67>
# class = tensor([0.])
# id = tensor([0.])
# confidence = 0.89
# center_point = (767, 719)
# center_point_uv = (1153, 719)
# --> point cloud = ()
# --> point world = ()
# <PIL.Image.Image image mode=RGB size=43x77>
# class = tensor([1.])
# id = tensor([1.])
# confidence = 0.88
# center_point = (828, 635)
# center_point_uv = (1092, 635)
# --> point cloud = ()
# --> point world = ()
# <PIL.Image.Image image mode=RGB size=92x63>
# class = tensor([2.])
# id = tensor([2.])
# confidence = 0.77
# center_point = (1075, 583)
# center_point_uv = (845, 583)
# --> point cloud = ()
# --> point world = ()
